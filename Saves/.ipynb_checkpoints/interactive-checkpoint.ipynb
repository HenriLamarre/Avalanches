# %%
import numpy as np
import matplotlib.pyplot as plt
import avalancher_interactive as av
import tools as tl
# %load_ext autoreload
# %autoreload 2
plt.rcParams['figure.figsize'] = [10, 5]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-94ed9b870b63> in <module>
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 import avalancher_interactive as av
#       4 import tools as tl
#       5 get_ipython().run_line_magic('load_ext', 'autoreload')
#
# ~/PycharmProjects/Avalanches/Saves/avalancher_interactive.py in <module>
#       9 import copy
#      10 import matplotlib.pyplot as plt
# ---> 11 import tools as tl
#      12
#      13
#
# ~/PycharmProjects/Avalanches/Saves/tools.py in <module>
#       2 import copy
#       3 import matplotlib.pyplot as plt
# ----> 4 import avalancher as av
#       5
#       6 def current(lattice, pos):
#
# ModuleNotFoundError: No module named 'avalancher'

# %%
avalanche1 = av.Avalanche(2, 32)
avalanche1.interactive_step(1e3,load = './', curv_type = 'A2', shuffle=False)
# Out:
# Achieved 93.33 %

# %%
avalanche2 = av.Avalanche(2, 32)
avalanche2.interactive_step(1e3,load = './', save='./', curv_type = '9stencil', shuffle=True)
# Out:
# Achieved 61.9 %

# %%
avalanche3 = av.Avalanche(2, 32)
avalanche3.interactive_step(1e6,load = './', save='./', curv_type = 'normal', shuffle=True)
# Out:
# Achieved 78.82 %
