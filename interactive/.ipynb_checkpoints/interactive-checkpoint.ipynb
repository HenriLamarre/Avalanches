# %%
import numpy as np
import matplotlib.pyplot as plt
import avalancher_interactive as av
import tools as tl
# %load_ext autoreload
# %autoreload 2
plt.rcParams['figure.figsize'] = [10, 15]

# %% [markdown]
# # A2 no shuffle

# %%
avalanche = av.Avalanche(2, 32)
avalanche.interactive_step(1e5,load = './', save='./', curv_type = 'A2', shuffle=False, append_lists=True)
avalanche = None
# Out:
# Achieved 47.66 %

# %% [markdown]
# # A2 shuffle

# %%
avalanche = av.Avalanche(2, 32)
avalanche.interactive_step(1e5,load = './', save='./', curv_type = 'A2', shuffle=True, append_lists=True)
avalanche = None

# %% [markdown]
# # 8 neighbours shuffle

# %%
avalanche = av.Avalanche(2, 32)
avalanche.interactive_step(1e5,load = './', save='./', curv_type = '9stencil', shuffle=True, append_lists=True)
avalanche = None
# Out:
# Achieved 44.42 %

# %% [markdown]
# # 8 neighbours no shuffle

# %%
avalanche = av.Avalanche(2, 32)
avalanche.interactive_step(1e5,load = './', save='./', curv_type = '9stencil', shuffle=False, append_lists=True)
avalanche = None
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-77e20a92a9e4> in <module>
#       1 avalanche = av.Avalanche(2, 32)
# ----> 2 avalanche.interactive_step(1e4,load = './', save='./', curv_type = '9stencil', shuffle=False, append_lists=True)
#       3 avalanche = None
#
# ~/PycharmProjects/Avalanches/interactive/avalancher_interactive.py in interactive_step(self, t_, save, load, shuffle, curv_type, append_lists)
#     169         if append_lists:
#     170             E,P,T = self.data_scanner()
# --> 171             E_ = self.hist_(E)
#     172             P_ = self.hist_(P)
#     173             T_ = self.hist_(T)
#
# ~/PycharmProjects/Avalanches/interactive/avalancher_interactive.py in hist_(self, array)
#     239         refined_x = x[hist[0] > 1e-10]
#     240         refined_hist = hist[0][hist[0] > 1e-10]
# ...

# %% [markdown]
# # normal shuffle

# %%
avalanche = av.Avalanche(2, 32)
avalanche.interactive_step(1e5,load = './', save='./', curv_type = 'normal', shuffle=True, append_lists=True)
avalanche = None

# %% [markdown]
# # Normal no shuffle

# %%
avalanche = av.Avalanche(2, 32)
avalanche.interactive_step(1e5,load = './', save='./', curv_type = 'normal', shuffle=False, append_lists=True)
avalanche = None
