# %%
import numpy as np
import matplotlib.pyplot as plt
import avalancher_interactive as av
import tools as tl
# %load_ext autoreload
# %autoreload 2
plt.rcParams['figure.figsize'] = [10, 15]

# %% [markdown]
# # Non conservative current

# %% [markdown]
# # Courbure2 no shuffle

# %%
avalanche = av.Avalanche(2, 32)
avalanche.interactive_step(1e6,load = './Saves/', save='./Saves/', curv_type = 'normal',
                           shuffle=True, append_lists=True, physical = False)
avalanche = None
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 avalanche = av.Avalanche(2, 32)
# ----> 2 avalanche.interactive_step(1e6,load = './Saves/', save='./Saves/', curv_type = 'normal',
#       3                            shuffle=True, append_lists=True, physical = False)
#       4 avalanche = None
#
# File ~/PycharmProjects/Avalanches/interactive/avalancher_interactive.py:189, in Avalanche.interactive_step(self, t_, save, load, shuffle, curv_type, append_lists, physical)
#     186 ax[1,0].set_title('Lattice Energy')
#     188 ax[2,0].scatter(np.log10(E_[1][E_[0][0] > 1e-10]), np.log10(E_[0][0][E_[0][0] > 1e-10]))
# --> 189 ax[2,0].plot(np.log10(E_[1]), self.line(np.log10(E_[1]), E_[2][0], E_[2][1]))
#     190 ax[2,0].set_title('Energy (slope = {})'.format(round(E_[2][0], 2)))
# ...

# %% [markdown]
# # courbure 2 shuffle

# %%
avalanche = av.Avalanche(2, 32)
avalanche.interactive_step(1e6,load = './', save='./', curv_type = 'A2', shuffle=True, append_lists=True)
avalanche = None
# Out:
# Achieved 58.14 %

# %% [markdown]
# # 8 neighbours shuffle

# %%
avalanche = av.Avalanche(2, 32)
avalanche.interactive_step(1e6,load = './', save='./', curv_type = '9stencil', shuffle=True, append_lists=True)
avalanche = None
# Out:
# Achieved 67.07 %

# %% [markdown]
# # normal shuffle

# %%
avalanche = av.Avalanche(2, 32)
avalanche.interactive_step(1e6,load = './', save='./', curv_type = 'normal', shuffle=True, append_lists=True)
avalanche = None
# Out:
# Achieved 84.37 %

# %% [markdown]
# # Normal no shuffle

# %%
avalanche = av.Avalanche(2, 32)
avalanche.interactive_step(1e6,load = './', save='./', curv_type = 'normal', shuffle=False, append_lists=True)
avalanche = None
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3557735/382338707.py in <cell line: 2>()
#       1 avalanche = av.Avalanche(2, 32)
# ----> 2 avalanche.interactive_step(1e6,load = './', save='./', curv_type = 'normal', shuffle=False, append_lists=True)
#       3 avalanche = None
#
# ~/PycharmProjects/Avalanches/interactive/avalancher_interactive.py in interactive_step(self, t_, save, load, shuffle, curv_type, append_lists)
#     169         else:
#     170             self.name = curv_type
# --> 171         self.loop(t_, load, save, shuffle, curv_type, append_lists)
#     172         if append_lists:
#     173             E,P,T = self.data_scanner()
#
# ~/PycharmProjects/Avalanches/interactive/avalancher_interactive.py in loop(self, total_time, load, save, shuffle, curv_type, append_lists)
# ...
